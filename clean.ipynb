# %%
#Import thư viện
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv("topcv.csv", encoding="utf-8-sig")
df_2 = pd.read_csv("careerviet.csv", encoding="utf-8-sig")
df_3 = pd.read_csv("vietnamworks.csv", encoding="utf-8-sig")

# %%
pd.set_option('display.max_columns', None)

# %%
df_1.head(2)
# Out:
#                         _id  \
# 0  694411612e8929610b079c85
# 1  6944116a2e8929610b079c86
#
#                                                title  \
# 0  Chuyên Viên Phân Tích Nghiệp Vụ Phần Mềm (Yêu ...
# 1                               Chuyên Viên Kiểm Thử
#
#                                              company  salary[0]     salary[1]  \
# 0                               CÔNG TY CỔ PHẦN MISA  Mức lương  Tới 25 triệu
# 1  CÔNG TY TNHH TỔNG CÔNG TY CÔNG NGHỆ & GIẢI PHÁ...  Mức lương    Thoả thuận
#
#   location[0] location[1] experience[0] experience[1]  \
# 0    Địa điểm      Hà Nội   Kinh nghiệm         1 năm
# 1    Địa điểm      Hà Nội   Kinh nghiệm         1 năm
#
#                                      company_name[0] company_name[1]  \
# 0                               Công ty Cổ phần MISA             NaN
# 1  Công ty TNHH Tổng công ty Công nghệ & Giải phá...             NaN
#
#   company_scale[0]    company_scale[1] company_field[0] company_field[1]  \
# 0          Quy mô:     3000+ nhân viên        Lĩnh vực:    IT - Phần mềm
# 1          Quy mô:  500-1000 nhân viên        Lĩnh vực:    IT - Phần mềm
#
#   company_address[0]                                 company_address[1]  \
# 0          Địa điểm:  Tầng 9 tòa nhà Technosoft ngõ 15 Duy Tân, Dịch...
# 1          Địa điểm:  Tầng 14 & 16, tòa nhà CMC, Duy Tân, Hà Nội, Vi...
#
#   company_address[2]     deadline[0] deadline[1]   tags.Yêu cầu:[0]  \
# 0                NaN  Hạn nộp hồ sơ:  03/01/2026  1 năm kinh nghiệm
# 1                NaN  Hạn nộp hồ sơ:  28/02/2026  1 năm kinh nghiệm
#
#   tags.Yêu cầu:[1] tags.Yêu cầu:[2] tags.Yêu cầu:[3] tags.Yêu cầu:[4]  \
# 0  Đại Học trở lên              NaN              NaN              NaN
# 1  Đại Học trở lên              NaN              NaN              NaN
#
#   tags.Yêu cầu:[5] tags.Yêu cầu:[6] tags.Yêu cầu:[7] tags.Yêu cầu:[8]  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
#
#   tags.Yêu cầu:[9] tags.Yêu cầu:[10] tags.Quyền lợi:[0] tags.Quyền lợi:[1]  \
# 0              NaN               NaN         Nghỉ thứ 7    Bảo hiểm xã hội
# 1              NaN               NaN         Nghỉ thứ 7                NaN
#
#   tags.Quyền lợi:[2]                     tags.Chuyên môn:[0]  \
# 0   Du lịch hàng năm  Business Analyst (Phân tích nghiệp vụ)
# 1                NaN                         Chuyên môn khác
#
#           tags.Chuyên môn:[1] tags.Chuyên môn:[2] tags.Chuyên môn:[3]  \
# 0                   Tài chính             Kế toán           Kiểm toán
# 1  IT - Phần cứng và máy tính                 NaN                 NaN
#
#   tags.Chuyên môn:[4] tags.Chuyên môn:[5] tags.Chuyên môn:[6]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   tags.Chuyên môn:[7] tags.Chuyên môn:[8] tags.Chuyên môn:[9]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   tags.Chuyên môn:[10]                       descriptions.Mô tả công việc  \
# 0                  NaN  Khảo sát và tiếp nhận thông tin về luồng nghiệ...
# 1                  NaN  • Lập kế hoạch kiểm thử • Nghiên cứu, phân tíc...
#
#                        descriptions.Yêu cầu ứng viên  \
# 0  Tốt nghiệp ĐH trở lên các chuyên ngành về Kế t...
# 1  • Tốt nghiệp Đại học trở lên chuyên ngành CNTT...
#
#                               descriptions.Quyền lợi  \
# 0  Nền tảng vững chắc cho phát triển sự nghiệp, t...
# 1  THU NHẬP Lương tháng thỏa thuận theo năng lực ...
#
#   descriptions.Địa điểm làm việc (đã được cập nhật theo Danh mục Hành chính mới)  \
# 0  - Hà Nội: Tòa nhà Technosoft, Ngõ 15 Duy Tân, ...
# 1              - Hà Nội: 11 Duy Tân, Phường Cầu Giấy
#
#       descriptions.Thời gian làm việc  \
# 0  Thứ 2 - Thứ 6 (từ 08:00 đến 17:30)
# 1  Thứ 2 - Thứ 6 (từ 08:15 đến 17:30)
#
#                     descriptions.Cách thức ứng tuyển source  \
# 0  Ứng viên nộp hồ sơ trực tuyến bằng cách bấm Ứn...  topcv
# 1  Ứng viên nộp hồ sơ trực tuyến bằng cách bấm Ứn...  topcv
#
#                    crawl_at descriptions.Thu nhập  \
# 0  2025-12-18T21:36:17.701Z                   NaN
# 1  2025-12-18T21:36:26.653Z                   NaN
#
#   descriptions.Địa điểm làm việc
# 0                            NaN
# 1                            NaN

# %%
df_1.columns.to_list()
# Out:
# ['_id',
#  'title',
#  'company',
#  'salary[0]',
#  'salary[1]',
#  'location[0]',
#  'location[1]',
#  'experience[0]',
#  'experience[1]',
#  'company_name[0]',
#  'company_name[1]',
#  'company_scale[0]',
#  'company_scale[1]',
#  'company_field[0]',
#  'company_field[1]',
#  'company_address[0]',
#  'company_address[1]',
#  'company_address[2]',
#  'deadline[0]',
#  'deadline[1]',
#  'tags.Yêu cầu:[0]',
#  'tags.Yêu cầu:[1]',
#  'tags.Yêu cầu:[2]',
#  'tags.Yêu cầu:[3]',
#  'tags.Yêu cầu:[4]',
#  'tags.Yêu cầu:[5]',
#  'tags.Yêu cầu:[6]',
#  'tags.Yêu cầu:[7]',
#  'tags.Yêu cầu:[8]',
#  'tags.Yêu cầu:[9]',
#  'tags.Yêu cầu:[10]',
#  'tags.Quyền lợi:[0]',
#  'tags.Quyền lợi:[1]',
#  'tags.Quyền lợi:[2]',
#  'tags.Chuyên môn:[0]',
#  'tags.Chuyên môn:[1]',
#  'tags.Chuyên môn:[2]',
#  'tags.Chuyên môn:[3]',
#  'tags.Chuyên môn:[4]',
#  'tags.Chuyên môn:[5]',
#  'tags.Chuyên môn:[6]',
#  'tags.Chuyên môn:[7]',
#  'tags.Chuyên môn:[8]',
#  'tags.Chuyên môn:[9]',
#  'tags.Chuyên môn:[10]',
#  'descriptions.Mô tả công việc',
#  'descriptions.Yêu cầu ứng viên',
#  'descriptions.Quyền lợi',
#  'descriptions.Địa điểm làm việc (đã được cập nhật theo Danh mục Hành chính mới)',
#  'descriptions.Thời gian làm việc',
#  'descriptions.Cách thức ứng tuyển',
#  'source',
#  'crawl_at',
#  'descriptions.Thu nhập',
#  'descriptions.Địa điểm làm việc']

# %%
df_2.head(2)
# Out:
#                         _id  \
# 0  694807cfcb490f02d21a3605
# 1  694807cfcb490f02d21a3606
#
#                                              job_url benefits[0]  \
# 0  https://careerviet.vn/vi/tim-viec-lam/network-...      Laptop
# 1  https://careerviet.vn/vi/tim-viec-lam/quality-...      Laptop
#
#        benefits[1] benefits[2]    benefits[3] benefits[4]    benefits[5]  \
# 0  Chế độ bảo hiểm     Du Lịch        Phụ cấp   Đồng phục  Chế độ thưởng
# 1  Chế độ bảo hiểm     Phụ cấp  Chế độ thưởng     Đào tạo     Tăng lương
#
#          benefits[6] benefits[7] benefits[8]   benefits[9]   benefits[10]  \
# 0  Chăm sóc sức khỏe     Đào tạo  Tăng lương  Công tác phí  Nghỉ phép năm
# 1      Nghỉ phép năm         NaN         NaN           NaN            NaN
#
#    benefits[11] benefits[12] benefits[13] benefits[14]  \
# 0  CLB thể thao          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
#
#                                              company  \
# 0  KDDI Vietnam - HCM GNOC (Ho Chi Minh Global Ne...
# 1                    Công Ty CP Dược Phẩm Pharmacity
#
#                    crawl_at    deadline       employment_type  experience  \
# 0  2025-12-21T21:44:31.423Z         NaN                   NaN         NaN
# 1  2025-12-21T21:44:31.836Z  05/01/2026  Nhân viên chính thức  7 - 15 Năm
#
#                                     industry  \
# 0                                        NaN
# 1  CNTT - Phần mềm , CNTT - Phần cứng / Mạng
#
#                                   job_description[0]  \
# 0  Liên lạc, liên kết với các đối tác (nhà mạng t...
# 1                                                NaN
#
#                                   job_description[1]  \
# 0  Phụ trách việc khảo sát, thiết lập, kiểm tra v...
# 1                                                NaN
#
#                                   job_description[2]  \
# 0  Phụ trách kế hoạch kiểm tra L1/L2/L3 IP, tunne...
# 1                                                NaN
#
#                                   job_description[3]  \
# 0  Hỗ trợ kỹ thuật cho bộ phần Điều hành mạng và ...
# 1                                                NaN
#
#                                   job_description[4]      job_description[5]  \
# 0  Giám sát tình trạng, chất lượng đường truyền m...  Ca sáng: 06:00 - 14:00
# 1                                                NaN                     NaN
#
#        job_description[6]     job_description[7] job_description[8]  \
# 0  Ca trưa: 14:00 - 22:00  Ca đêm: 22:00 - 06:00                NaN
# 1                     NaN                    NaN                NaN
#
#   job_description[9] job_description[10] job_description[11]  \
# 0                NaN                 NaN                 NaN
# 1                NaN                 NaN                 NaN
#
#   job_description[12] job_description[13] job_description[14]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[15] job_description[16] job_description[17]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[18] job_description[19] job_description[20]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[21] job_description[22] job_description[23]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[24] job_description[25] job_description[26]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[27] job_description[28] job_description[29]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[30] job_description[31]    job_requirement[0]  \
# 0                 NaN                 NaN  Độ tuổi từ 21 đến 26
# 1                 NaN                 NaN                   NaN
#
#                                   job_requirement[1]  \
# 0  Chuyên ngành Công nghệ thông tin, Mạng máy tín...
# 1                                                NaN
#
#                                   job_requirement[2]  \
# 0  Sinh viên năm cuối (Có thể làm việc toàn thời ...
# 1                                                NaN
#
#                     job_requirement[3]  \
# 0  Tiếng Anh Giao Tiếp khá tốt trở lên
# 1                                  NaN
#
#                                   job_requirement[4]  \
# 0  Thái độ làm việc tích cực, sẵn sàng học hỏi và...
# 1                                                NaN
#
#                          job_requirement[5] job_requirement[6]  \
# 0  Làm việc xoay xa, có thể làm vào ngày lễ                NaN
# 1                                       NaN                NaN
#
#   job_requirement[7] job_requirement[8] job_requirement[9]  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
#
#   job_requirement[10] job_requirement[11] job_requirement[12]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[13] job_requirement[14] job_requirement[15]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[16] job_requirement[17] job_requirement[18]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[19] job_requirement[20] job_requirement[21]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[22] job_requirement[23] job_requirement[24]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[25] job_requirement[26] job_requirement[27]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[28] job_requirement[29] job_requirement[30]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[31] job_requirement[32] job_requirement[33]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[34] job_requirement[35] job_requirement[36]    level  \
# 0                 NaN                 NaN                 NaN      NaN
# 1                 NaN                 NaN                 NaN  Quản lý
#
#    location[0] location[1] location[2]      other_info[0]  \
# 0  Hồ Chí Minh         NaN         NaN  Bằng cấp: Đại học
# 1  Hồ Chí Minh         NaN         NaN  Bằng cấp: Đại học
#
#                      other_info[1]                other_info[2]  \
# 0  Hình thức: Nhân viên chính thức  Thời gian thử việc: 2 tháng
# 1     Độ tuổi: Không giới hạn tuổi            Lương: Cạnh tranh
#
#                   other_info[3]                            other_info[4]  \
# 0  Độ tuổi: Không giới hạn tuổi  Thời gian làm việc: Trung bình 40h/tuần
# 1                           NaN                                      NaN
#
#               other_info[5] other_info[6] other_info[7] other_info[8]  \
# 0  Lương: 11 Tr - 13 Tr VND           NaN           NaN           NaN
# 1                       NaN           NaN           NaN           NaN
#
#   other_info[9] other_info[10]             salary  \
# 0           NaN            NaN  11 Tr - 13 Tr VND
# 1           NaN            NaN         Cạnh tranh
#
#                                            skills[0]  \
# 0  network engineer - kỹ sư mạng không yêu cầu ki...
# 1  quality assurance manager test automation manager
#
#                       skills[1]                  skills[2]  \
# 0         network administrator  chuyên viên quản trị mạng
# 1  nhân viên quản lý chất lượng            quality control
#
#                  skills[3]            skills[4] skills[5]         skills[6]  \
# 0  nhân viên quản trị mạng  kỹ sư quản trị mạng  it admin  it administrator
# 1                      NaN                  NaN       NaN               NaN
#
#   skills[7] skills[8] skills[9] skills[10] skills[11] skills[12] skills[13]  \
# 0       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 1       NaN       NaN       NaN        NaN        NaN        NaN        NaN
#
#   skills[14] skills[15] skills[16] skills[17] skills[18] skills[19]  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#   skills[20] skills[21] skills[22] skills[23] skills[24] skills[25]  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#   skills[26]      source                                              title  \
# 0        NaN  careerviet  Network Engineer - Kỹ Sư Mạng (Không Yêu Cầu K...
# 1        NaN  careerviet  Quality Assurance Manager (Test Automation Man...
#
#    updated_at
# 0         NaN
# 1  17/12/2025

# %%
df_2.columns.to_list()
# Out:
# ['_id',
#  'job_url',
#  'benefits[0]',
#  'benefits[1]',
#  'benefits[2]',
#  'benefits[3]',
#  'benefits[4]',
#  'benefits[5]',
#  'benefits[6]',
#  'benefits[7]',
#  'benefits[8]',
#  'benefits[9]',
#  'benefits[10]',
#  'benefits[11]',
#  'benefits[12]',
#  'benefits[13]',
#  'benefits[14]',
#  'company',
#  'crawl_at',
#  'deadline',
#  'employment_type',
#  'experience',
#  'industry',
#  'job_description[0]',
#  'job_description[1]',
#  'job_description[2]',
#  'job_description[3]',
#  'job_description[4]',
#  'job_description[5]',
#  'job_description[6]',
#  'job_description[7]',
#  'job_description[8]',
#  'job_description[9]',
#  'job_description[10]',
#  'job_description[11]',
#  'job_description[12]',
#  'job_description[13]',
#  'job_description[14]',
#  'job_description[15]',
#  'job_description[16]',
#  'job_description[17]',
#  'job_description[18]',
#  'job_description[19]',
#  'job_description[20]',
#  'job_description[21]',
#  'job_description[22]',
#  'job_description[23]',
#  'job_description[24]',
#  'job_description[25]',
#  'job_description[26]',
#  'job_description[27]',
#  'job_description[28]',
#  'job_description[29]',
#  'job_description[30]',
#  'job_description[31]',
#  'job_requirement[0]',
#  'job_requirement[1]',
#  'job_requirement[2]',
#  'job_requirement[3]',
#  'job_requirement[4]',
#  'job_requirement[5]',
#  'job_requirement[6]',
#  'job_requirement[7]',
#  'job_requirement[8]',
#  'job_requirement[9]',
#  'job_requirement[10]',
#  'job_requirement[11]',
#  'job_requirement[12]',
#  'job_requirement[13]',
#  'job_requirement[14]',
#  'job_requirement[15]',
#  'job_requirement[16]',
#  'job_requirement[17]',
#  'job_requirement[18]',
#  'job_requirement[19]',
#  'job_requirement[20]',
#  'job_requirement[21]',
#  'job_requirement[22]',
#  'job_requirement[23]',
#  'job_requirement[24]',
#  'job_requirement[25]',
#  'job_requirement[26]',
#  'job_requirement[27]',
#  'job_requirement[28]',
#  'job_requirement[29]',
#  'job_requirement[30]',
#  'job_requirement[31]',
#  'job_requirement[32]',
#  'job_requirement[33]',
#  'job_requirement[34]',
#  'job_requirement[35]',
#  'job_requirement[36]',
#  'level',
#  'location[0]',
#  'location[1]',
#  'location[2]',
#  'other_info[0]',
#  'other_info[1]',
#  'other_info[2]',
#  'other_info[3]',
#  'other_info[4]',
#  'other_info[5]',
#  'other_info[6]',
#  'other_info[7]',
#  'other_info[8]',
#  'other_info[9]',
#  'other_info[10]',
#  'salary',
#  'skills[0]',
#  'skills[1]',
#  'skills[2]',
#  'skills[3]',
#  'skills[4]',
#  'skills[5]',
#  'skills[6]',
#  'skills[7]',
#  'skills[8]',
#  'skills[9]',
#  'skills[10]',
#  'skills[11]',
#  'skills[12]',
#  'skills[13]',
#  'skills[14]',
#  'skills[15]',
#  'skills[16]',
#  'skills[17]',
#  'skills[18]',
#  'skills[19]',
#  'skills[20]',
#  'skills[21]',
#  'skills[22]',
#  'skills[23]',
#  'skills[24]',
#  'skills[25]',
#  'skills[26]',
#  'source',
#  'title',
#  'updated_at']

# %%
df_3.head(2)
# Out:
#                         _id   job_id                      job_title  \
# 0  6947d9dbbd1b5428d8f72065  1978922                 QA Game Tester
# 1  6947d9dbbd1b5428d8f72066  1973440  Data and Analytics Supervisor
#
#                                              job_url  \
# 0  https://www.vietnamworks.com/qa-game-tester--1...
# 1  https://www.vietnamworks.com/data-and-analytic...
#
#                    company_name salary_currency  salary  salary_min  \
# 0  Nexon Networks Vina Co. Ltd,             USD       0           0
# 1       Amway Vietnam Co., Ltd.             USD       0           0
#
#    salary_max pretty_salary  \
# 0           0  Thương lượng
# 1           0  Thương lượng
#
#                                   job_description[0]  \
# 0  Chúng tôi tuyển dụng Nhân viên kiểm soát chất ...
# 1        1. Business Performance Review and Analysis
#
#                                   job_description[1]  \
# 0  Ứng viên đủ tiêu chuẩn cần có đôi mắt tinh tườ...
# 1  • Collect, analyze, and centralize business da...
#
#                                   job_description[2]  \
# 0  Ứng viên CẦN mô tả kinh nghiệm chơi Game hoặc ...
# 1  • Develop efficient methods to extract, query,...
#
#                                   job_description[3]  \
# 0                     • Vị trí: nhân viên chính thức
# 1  • Prepare regular performance reports and pres...
#
#                                   job_description[4]  \
# 0                                   Mô tả công việc:
# 1  • Provide analytical support for deep-dive stu...
#
#                         job_description[5]  \
# 0  • Kiểm soát nội dung cơ bản trong game.
# 1            2. Consumer & Market Research
#
#                                   job_description[6]  \
# 0  • Kiểm soát các chức năng có độ phức tạp khác ...
# 1  • Assist in coordinating with external researc...
#
#                                   job_description[7]  \
# 0      • Nội dung kiểm tra liên quan đến dữ liệu số.
# 1  • Support internal surveys and research projec...
#
#                                   job_description[8]  \
# 0  • Báo cáo lỗi bằng cách sử dụng các công cụ th...
# 1  • Conduct desk research to compile market tren...
#
#                                   job_description[9]  \
# 0  • Hỗ trợ các thử nghiệm khác nhau, xem xét các...
# 1                                                NaN
#
#                                  job_description[10]  \
# 0  Đối với ứng viên đã có kinh nghiệm, bạn được y...
# 1                                                NaN
#
#                                  job_description[11] job_description[12]  \
# 0  • Làm việc với nhóm Kiểm soát chất lượng ở Hàn...    • Rà soát dự án.
# 1                                                NaN                 NaN
#
#                job_description[13]                      job_description[14]  \
# 0  • Viết tình huống kiểm tra lỗi.  • Kiểm soát nội dung mới và quan trọng.
# 1                              NaN                                      NaN
#
#                             job_description[15]  \
# 0  • Kiểm soát các chức năng có độ phức tạp cao
# 1                                           NaN
#
#                             job_description[16]  \
# 0  • Kiểm soát sản phẩm trả phí và tính khả thi
# 1                                           NaN
#
#                                  job_description[17]  \
# 0  • Kiểm soát theo các tiêu chí đánh giá trên nề...
# 1                                                NaN
#
#                 job_description[18]  \
# 0  • Kiểm soát quá trình đối chiếu.
# 1                               NaN
#
#                                  job_description[19] job_description[20]  \
# 0  • Quản lý và phân công công việc trong nhóm, đ...                 NaN
# 1                                                NaN                 NaN
#
#   job_description[21] job_description[22] job_description[23]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[24] job_description[25] job_description[26]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[27] job_description[28] job_description[29]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[30] job_description[31] job_description[32]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[33] job_description[34] job_description[35]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[36] job_description[37] job_description[38]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[39] job_description[40] job_description[41]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[42] job_description[43] job_description[44]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[45] job_description[46] job_description[47]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[48] job_description[49] job_description[50]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[51] job_description[52] job_description[53]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[54] job_description[55] job_description[56]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[57] job_description[58] job_description[59]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[60] job_description[61] job_description[62]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[63] job_description[64] job_description[65]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[66] job_description[67] job_description[68]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_description[69] job_description[70] job_description[71]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#                                   job_requirement[0]  \
# 0                                  YÊU CẦU CÔNG VIỆC
# 1  • A business-acumen mindset with 5+ years of e...
#
#                                   job_requirement[1]  \
# 0                                   • Mới tốt nghiệp
# 1  • Bachelor’s degree or higher in Economics, Da...
#
#                                   job_requirement[2]  \
# 0                       • Bằng cấp: Cao Đẳng trở lên
# 1  • Proficient in GCP/MySQL and experienced in P...
#
#                                   job_requirement[3]  \
# 0                       • Ưu tiên độ tuổi từ 20 - 27
# 1  • Strong ability to analyze data, generate ins...
#
#                                   job_requirement[4]  \
# 0  • Có kiến thức và đam mê chơi game. (Vui lòng ...
# 1  • Skilled in cross-functional project manageme...
#
#                                   job_requirement[5]  \
# 0      • Chủ động học hỏi và tiếp thu kiến thức mới.
# 1  • Excellent communication skills in both Engli...
#
#                                   job_requirement[6]  \
# 0                             • Thành thạo MS Office
# 1  • Strong sense of adaptability, analytical thi...
#
#                                 job_requirement[7]  \
# 0  • Kỹ năng đọc và viết tiếng Anh là một lợi thế.
# 1                                              NaN
#
#                                   job_requirement[8]  \
# 0  • Có tinh thần đồng đội, kỷ luật và tuân thủ c...
# 1                                                NaN
#
#                                   job_requirement[9] job_requirement[10]  \
# 0  • Quyết tâm đem lại dịch vụ chất lượng cao cho...           Phúc lợi:
# 1                                                NaN                 NaN
#
#                                  job_requirement[11]  \
# 0  • Thời gian làm việc: 8 tiếng/ngày [9:00 - 18:...
# 1                                                NaN
#
#                             job_requirement[12]  \
# 0  • Trang phục: phù hợp với môi trường công ty
# 1                                           NaN
#
#                                  job_requirement[13]  \
# 0  • Cơ hội làm việc trong các dự án toàn cầu với...
# 1                                                NaN
#
#                      job_requirement[14]                  job_requirement[15]  \
# 0  • Mức lương và chế độ đãi ngộ hấp dẫn  • Môi trường làm việc chuyên nghiệp
# 1                                    NaN                                  NaN
#
#                                job_requirement[16]  \
# 0  • Lương tháng 13 hằng năm ít nhất 1 tháng lương
# 1                                              NaN
#
#                        job_requirement[17]  \
# 0  • Phụ cấp ăn trưa, tiền ăn khi tăng ca.
# 1                                      NaN
#
#                           job_requirement[18]  \
# 0  • Hỗ trợ xe Grab đưa đón khi làm thêm giờ.
# 1                                         NaN
#
#                                  job_requirement[19]  \
# 0  • Đóng Bảo hiểm xã hội và thanh toán làm thêm ...
# 1                                                NaN
#
#                                  job_requirement[20]  \
# 0  • Đánh giá lương hàng năm dựa trên hiệu suất l...
# 1                                                NaN
#
#                                  job_requirement[21]  \
# 0  • Du lịch công ty hàng năm, Tiệc cuối năm, Sin...
# 1                                                NaN
#
#                                  job_requirement[22] job_requirement[23]  \
# 0  • Văn hóa mở, nơi mọi nhân viên đều được coi t...                 NaN
# 1                                                NaN                 NaN
#
#   job_requirement[24] job_requirement[25] job_requirement[26]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[27] job_requirement[28] job_requirement[29]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[30] job_requirement[31] job_requirement[32]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[33] job_requirement[34] job_requirement[35]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[36] job_requirement[37] job_requirement[38]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[39] job_requirement[40] job_requirement[41]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[42] job_requirement[43] job_requirement[44]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[45] job_requirement[46] job_requirement[47]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[48] job_requirement[49] job_requirement[50]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[51] job_requirement[52] job_requirement[53]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[54] job_requirement[55] job_requirement[56]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[57] job_requirement[58] job_requirement[59]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[60] job_requirement[61] job_requirement[62]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[63] job_requirement[64] job_requirement[65]  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   job_requirement[66]  years_of_experience min_degree working_locations[0]  \
# 0                 NaN                    0   Cao đẳng          Hồ Chí Minh
# 1                 NaN                    5    Cử nhân          Hồ Chí Minh
#
#   working_locations[1] working_locations[2]  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
#
#                                              address language_selected_vi  \
# 0  UOA Tower, 6 Tan Trao Street, Tan Phu Ward, Di...               Bất kỳ
# 1  HCMC AMWAY CENTER - 410B,C,D Nguyễn Thị Minh K...            Tiếng Anh
#
#   job_level_vi                 created_on                approved_on  \
# 0    Nhân viên  2025-11-06T16:07:05+07:00  2025-12-08T10:58:29+07:00
# 1    Nhân viên  2025-10-23T16:30:36+07:00  2025-11-24T10:33:36+07:00
#
#                   expired_on      crawl_at                industries_v3[0]  \
# 0  2026-01-07T23:59:59+07:00  1.766312e+09  Phần Mềm CNTT/Dịch vụ Phần mềm
# 1  2025-12-24T23:59:59+07:00  1.766312e+09                  Hàng tiêu dùng
#
#                     industries[0]      skills[0]          skills[1]  \
# 0  Phần Mềm CNTT/Dịch vụ Phần mềm   Game Testing  Quality Assurance
# 1                  Hàng tiêu dùng  Data Analysis           Power BI
#
#         skills[2]              skills[3]            skills[4] skills[5]  \
# 0  Manual Testing                English           Test Cases       NaN
# 1             SQL  Business Intelligence  Commercial Analysis       NaN
#
#   skills[6] skills[7] skills[8] skills[9]  \
# 0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN
#
#                                 benefits.Thưởng  \
# 0  From 12 days Annual leave, 13th month salary
# 1         13th Month + Annual Performance Bonus
#
#                           benefits.Chăm sóc sức khoẻ  \
# 0          Support lunch fee and premium health care
# 1  Premium Healthcare Insurance for Employee & Fa...
#
#                                benefits.Đào tạo  \
# 0  Team building, Activities, Training sessions
# 1   Personal Development and Career Advancement
#
#               group_job_functions                  job_functions  \
# 0  Công Nghệ Thông Tin/Viễn Thông         QA/QC/Software Testing
# 1  Công Nghệ Thông Tin/Viễn Thông  Data Engineer/Data Analyst/AI
#
#   benefits.Nghỉ phép có lương benefits.Khác benefits.Cơ hội du lịch  \
# 0                         NaN           NaN                     NaN
# 1                         NaN           NaN                     NaN
#
#   benefits.Máy tính xách tay benefits.Giải thưởng benefits.Hoạt động nhóm  \
# 0                        NaN                  NaN                     NaN
# 1                        NaN                  NaN                     NaN
#
#   benefits.Xe đưa đón benefits.Căn-tin benefits.Điện thoại benefits.Thư viện  \
# 0                 NaN              NaN                 NaN               NaN
# 1                 NaN              NaN                 NaN               NaN
#
#   benefits.Nhà trẻ benefits.Phiếu giảm giá
# 0              NaN                     NaN
# 1              NaN                     NaN

# %%
df_3.columns.to_list()
# Out:
# ['_id',
#  'job_id',
#  'job_title',
#  'job_url',
#  'company_name',
#  'salary_currency',
#  'salary',
#  'salary_min',
#  'salary_max',
#  'pretty_salary',
#  'job_description[0]',
#  'job_description[1]',
#  'job_description[2]',
#  'job_description[3]',
#  'job_description[4]',
#  'job_description[5]',
#  'job_description[6]',
#  'job_description[7]',
#  'job_description[8]',
#  'job_description[9]',
#  'job_description[10]',
#  'job_description[11]',
#  'job_description[12]',
#  'job_description[13]',
#  'job_description[14]',
#  'job_description[15]',
#  'job_description[16]',
#  'job_description[17]',
#  'job_description[18]',
#  'job_description[19]',
#  'job_description[20]',
#  'job_description[21]',
#  'job_description[22]',
#  'job_description[23]',
#  'job_description[24]',
#  'job_description[25]',
#  'job_description[26]',
#  'job_description[27]',
#  'job_description[28]',
#  'job_description[29]',
#  'job_description[30]',
#  'job_description[31]',
#  'job_description[32]',
#  'job_description[33]',
#  'job_description[34]',
#  'job_description[35]',
#  'job_description[36]',
#  'job_description[37]',
#  'job_description[38]',
#  'job_description[39]',
#  'job_description[40]',
#  'job_description[41]',
#  'job_description[42]',
#  'job_description[43]',
#  'job_description[44]',
#  'job_description[45]',
#  'job_description[46]',
#  'job_description[47]',
#  'job_description[48]',
#  'job_description[49]',
#  'job_description[50]',
#  'job_description[51]',
#  'job_description[52]',
#  'job_description[53]',
#  'job_description[54]',
#  'job_description[55]',
#  'job_description[56]',
#  'job_description[57]',
#  'job_description[58]',
#  'job_description[59]',
#  'job_description[60]',
#  'job_description[61]',
#  'job_description[62]',
#  'job_description[63]',
#  'job_description[64]',
#  'job_description[65]',
#  'job_description[66]',
#  'job_description[67]',
#  'job_description[68]',
#  'job_description[69]',
#  'job_description[70]',
#  'job_description[71]',
#  'job_requirement[0]',
#  'job_requirement[1]',
#  'job_requirement[2]',
#  'job_requirement[3]',
#  'job_requirement[4]',
#  'job_requirement[5]',
#  'job_requirement[6]',
#  'job_requirement[7]',
#  'job_requirement[8]',
#  'job_requirement[9]',
#  'job_requirement[10]',
#  'job_requirement[11]',
#  'job_requirement[12]',
#  'job_requirement[13]',
#  'job_requirement[14]',
#  'job_requirement[15]',
#  'job_requirement[16]',
#  'job_requirement[17]',
#  'job_requirement[18]',
#  'job_requirement[19]',
#  'job_requirement[20]',
#  'job_requirement[21]',
#  'job_requirement[22]',
#  'job_requirement[23]',
#  'job_requirement[24]',
#  'job_requirement[25]',
#  'job_requirement[26]',
#  'job_requirement[27]',
#  'job_requirement[28]',
#  'job_requirement[29]',
#  'job_requirement[30]',
#  'job_requirement[31]',
#  'job_requirement[32]',
#  'job_requirement[33]',
#  'job_requirement[34]',
#  'job_requirement[35]',
#  'job_requirement[36]',
#  'job_requirement[37]',
#  'job_requirement[38]',
#  'job_requirement[39]',
#  'job_requirement[40]',
#  'job_requirement[41]',
#  'job_requirement[42]',
#  'job_requirement[43]',
#  'job_requirement[44]',
#  'job_requirement[45]',
#  'job_requirement[46]',
#  'job_requirement[47]',
#  'job_requirement[48]',
#  'job_requirement[49]',
#  'job_requirement[50]',
#  'job_requirement[51]',
#  'job_requirement[52]',
#  'job_requirement[53]',
#  'job_requirement[54]',
#  'job_requirement[55]',
#  'job_requirement[56]',
#  'job_requirement[57]',
#  'job_requirement[58]',
#  'job_requirement[59]',
#  'job_requirement[60]',
#  'job_requirement[61]',
#  'job_requirement[62]',
#  'job_requirement[63]',
#  'job_requirement[64]',
#  'job_requirement[65]',
#  'job_requirement[66]',
#  'years_of_experience',
#  'min_degree',
#  'working_locations[0]',
#  'working_locations[1]',
#  'working_locations[2]',
#  'address',
#  'language_selected_vi',
#  'job_level_vi',
#  'created_on',
#  'approved_on',
#  'expired_on',
#  'crawl_at',
#  'industries_v3[0]',
#  'industries[0]',
#  'skills[0]',
#  'skills[1]',
#  'skills[2]',
#  'skills[3]',
#  'skills[4]',
#  'skills[5]',
#  'skills[6]',
#  'skills[7]',
#  'skills[8]',
#  'skills[9]',
#  'benefits.Thưởng',
#  'benefits.Chăm sóc sức khoẻ',
#  'benefits.Đào tạo',
#  'group_job_functions',
#  'job_functions',
#  'benefits.Nghỉ phép có lương',
#  'benefits.Khác',
#  'benefits.Cơ hội du lịch',
#  'benefits.Máy tính xách tay',
#  'benefits.Giải thưởng',
#  'benefits.Hoạt động nhóm',
#  'benefits.Xe đưa đón',
#  'benefits.Căn-tin',
#  'benefits.Điện thoại',
#  'benefits.Thư viện',
#  'benefits.Nhà trẻ',
#  'benefits.Phiếu giảm giá']

# %%
df_1 = df_1[[
    'tags.Chuyên môn:[0]',
    'deadline[1]',
    'salary[1]',
    'location[1]'
]]

# %%
df_1
# Out:
#                          tags.Chuyên môn:[0] deadline[1]      salary[1]  \
# 0     Business Analyst (Phân tích nghiệp vụ)  03/01/2026   Tới 25 triệu
# 1                            Chuyên môn khác  28/02/2026     Thoả thuận
# 2                          Software Engineer  16/01/2026  40 - 60 triệu
# 3     Business Analyst (Phân tích nghiệp vụ)  15/01/2026     Thoả thuận
# 4                        Kinh doanh phần mềm  15/01/2026    Từ 20 triệu
# ...                                      ...         ...            ...
# 1075                          Cloud Engineer  31/12/2025  23 - 27 triệu
# 1076        Thiết kế đồ họa (Graphic Design)  24/12/2025     Thoả thuận
# 1077                        Network Engineer  24/12/2025     Thoả thuận
# 1078        Thiết kế đồ họa (Graphic Design)  24/12/2025    4 - 6 triệu
# 1079        Thiết kế đồ họa (Graphic Design)  31/12/2025  12 - 17 triệu
#
#             location[1]
# 0                Hà Nội
# 1                Hà Nội
# 2     Hồ Chí Minh (mới)
# 3                Hà Nội
# 4     Hồ Chí Minh (mới)
# ...                 ...
# 1075             Hà Nội
# 1076  Hồ Chí Minh (mới)
# 1077             Hà Nội
# 1078             Hà Nội
# 1079             Hà Nội
#
# [1080 rows x 4 columns]

# %%
df_2 = df_2[[
    'title',
    'deadline',
    'salary',
    'location[0]'
]]

# %%
df_2
# Out:
#                                                   title    deadline  \
# 0     Network Engineer - Kỹ Sư Mạng (Không Yêu Cầu K...         NaN
# 1     Quality Assurance Manager (Test Automation Man...  05/01/2026
# 2                    Threat and Process Compliance Lead         NaN
# 3     Sales Leader B2B/ Trưởng Nhóm Kinh Doanh Phần ...  25/12/2025
# 4                           Chuyên viên ERP (SAP 4HANA)         NaN
# ...                                                 ...         ...
# 1086             Backend Developer Intern (NodeJS/Java)  31/12/2025
# 1087  Thực tập sinh Developer ( Không trợ cấp, Hỗ tr...  20/12/2025
# 1088                                 AI Engineer Intern  31/12/2025
# 1089                           Thực tập sinh kinh doanh  25/12/2025
# 1090                                  Thực Tập Sinh SEO  11/12/2025
#
#                  salary  location[0]
# 0     11 Tr - 13 Tr VND  Hồ Chí Minh
# 1            Cạnh tranh  Hồ Chí Minh
# 2            Cạnh tranh  Hồ Chí Minh
# 3     15 Tr - 40 Tr VND  Hồ Chí Minh
# 4            Cạnh tranh  Hồ Chí Minh
# ...                 ...          ...
# 1086  2 Tr - 2,4 Tr VND  Hồ Chí Minh
# 1087         Cạnh tranh  Hồ Chí Minh
# 1088    1 Tr - 2 Tr VND  Hồ Chí Minh
# 1089      Trên 2 Tr VND  Hồ Chí Minh
# 1090    2 Tr - 4 Tr VND  Hồ Chí Minh
#
# [1091 rows x 4 columns]

# %%
df_3 = df_3[[
    'job_title',
    'expired_on',
    'pretty_salary',
    'working_locations[0]'
]]

# %%
df_3
# Out:
#                                              job_title  \
# 0                                       QA Game Tester
# 1                        Data and Analytics Supervisor
# 2    AI Engineer (Computer Vision/NPL/LLM) - Khối C...
# 3    FullStack Developer (Junior, Senior) - Khối Cô...
# 4                                         Nhân Viên IT
# ..                                                 ...
# 704                      Database Reliability Engineer
# 705                     IT Security & Support Engineer
# 706    ERP Application Engineer (Factory In Hai Phong)
# 707                  Nhân Viên Kỹ Thuật (máy xây dựng)
# 708                                     Java Developer
#
#                     expired_on       pretty_salary working_locations[0]
# 0    2026-01-07T23:59:59+07:00        Thương lượng          Hồ Chí Minh
# 1    2025-12-24T23:59:59+07:00        Thương lượng          Hồ Chí Minh
# 2    2025-12-27T23:59:59+07:00        Thương lượng               Hà Nội
# 3    2025-12-27T23:59:59+07:00        Thương lượng               Hà Nội
# 4    2025-12-24T23:59:59+07:00   13tr-15tr ₫/tháng            Hải Phòng
# ..                         ...                 ...                  ...
# 704  2025-12-21T23:59:59+07:00  $ 65tr-80tr /tháng          Hồ Chí Minh
# 705  2025-12-21T23:59:59+07:00        Thương lượng               Hà Nội
# 706  2025-12-21T23:59:59+07:00        Thương lượng            Hải Phòng
# 707  2025-12-21T23:59:59+07:00   12tr-25tr ₫/tháng                  NaN
# 708  2025-12-21T23:59:59+07:00    $ 750-950 /tháng          Hồ Chí Minh
#
# [709 rows x 4 columns]

# %%
df_1 = df_1.rename(columns={
    'tags.Chuyên môn:[0]' : 'job_title',
    'deadline[1]' : 'date',
    'salary[1]' : 'salary',
    'location[1]' : 'location'
})

# %%
df_2 = df_2.rename(columns={
    'title' : 'job_title',
    'deadline' : 'date',
    'salary' : 'salary',
    'location[0]' : 'location'
})

# %%
df_3 = df_3.rename(columns={
    'expired_on' : 'date',
    'pretty_salary' : 'salary',
    'working_locations[0]' : 'location'
})

# %%
df_1
# Out:
#                                    job_title        date         salary  \
# 0     Business Analyst (Phân tích nghiệp vụ)  03/01/2026   Tới 25 triệu
# 1                            Chuyên môn khác  28/02/2026     Thoả thuận
# 2                          Software Engineer  16/01/2026  40 - 60 triệu
# 3     Business Analyst (Phân tích nghiệp vụ)  15/01/2026     Thoả thuận
# 4                        Kinh doanh phần mềm  15/01/2026    Từ 20 triệu
# ...                                      ...         ...            ...
# 1075                          Cloud Engineer  31/12/2025  23 - 27 triệu
# 1076        Thiết kế đồ họa (Graphic Design)  24/12/2025     Thoả thuận
# 1077                        Network Engineer  24/12/2025     Thoả thuận
# 1078        Thiết kế đồ họa (Graphic Design)  24/12/2025    4 - 6 triệu
# 1079        Thiết kế đồ họa (Graphic Design)  31/12/2025  12 - 17 triệu
#
#                location
# 0                Hà Nội
# 1                Hà Nội
# 2     Hồ Chí Minh (mới)
# 3                Hà Nội
# 4     Hồ Chí Minh (mới)
# ...                 ...
# 1075             Hà Nội
# 1076  Hồ Chí Minh (mới)
# 1077             Hà Nội
# 1078             Hà Nội
# 1079             Hà Nội
#
# [1080 rows x 4 columns]

# %%
import re

# %%
def clean_job_title(title):
    if pd.isna(title):
        return title
    
    s = str(title)
    
    # 1. Bỏ số + dấu phẩy ở đầu
    s = re.sub(r'^\d+,\s*', '', s)
    
    # 2. Bỏ tất cả nội dung trong () và []
    s = re.sub(r'\(.*?\)', '', s)
    s = re.sub(r'\[.*?\]', '', s)
    
    # 3. Bỏ các từ khóa tuyển dụng dư thừa
    s = re.sub(r'Tuyển Dụng|TUYỂN DỤNG', '', s, flags=re.IGNORECASE)
    
    # 4. Bỏ ký tự _ hoặc - dư
    s = re.sub(r'[_\-]+', ' ', s)
    
    # 5. Chuẩn hóa khoảng trắng
    s = re.sub(r'\s+', ' ', s)
    
    return s.strip()

# %%
dfs = {
    "df_1" : df_1,
    "df_2" : df_2,
    "df_3" : df_3
}
for name, df in dfs.items():
    if 'job_title' in df.columns:
        df['job_title'] = df['job_title'].apply(clean_job_title)
        df.dropna(subset=['job_title'], inplace=True)

# %%
df_1
# Out:
#                 job_title        date         salary           location
# 0        Business Analyst  03/01/2026   Tới 25 triệu             Hà Nội
# 1         Chuyên môn khác  28/02/2026     Thoả thuận             Hà Nội
# 2       Software Engineer  16/01/2026  40 - 60 triệu  Hồ Chí Minh (mới)
# 3        Business Analyst  15/01/2026     Thoả thuận             Hà Nội
# 4     Kinh doanh phần mềm  15/01/2026    Từ 20 triệu  Hồ Chí Minh (mới)
# ...                   ...         ...            ...                ...
# 1075       Cloud Engineer  31/12/2025  23 - 27 triệu             Hà Nội
# 1076      Thiết kế đồ họa  24/12/2025     Thoả thuận  Hồ Chí Minh (mới)
# 1077     Network Engineer  24/12/2025     Thoả thuận             Hà Nội
# 1078      Thiết kế đồ họa  24/12/2025    4 - 6 triệu             Hà Nội
# 1079      Thiết kế đồ họa  31/12/2025  12 - 17 triệu             Hà Nội
#
# [1070 rows x 4 columns]

# %%
df_2
# Out:
#                                               job_title        date  \
# 0                           Network Engineer Kỹ Sư Mạng         NaN
# 1                             Quality Assurance Manager  05/01/2026
# 2                    Threat and Process Compliance Lead         NaN
# 3     Sales Leader B2B/ Trưởng Nhóm Kinh Doanh Phần ...  25/12/2025
# 4                                       Chuyên viên ERP         NaN
# ...                                                 ...         ...
# 1086                           Backend Developer Intern  31/12/2025
# 1087                            Thực tập sinh Developer  20/12/2025
# 1088                                 AI Engineer Intern  31/12/2025
# 1089                           Thực tập sinh kinh doanh  25/12/2025
# 1090                                  Thực Tập Sinh SEO  11/12/2025
#
#                  salary     location
# 0     11 Tr - 13 Tr VND  Hồ Chí Minh
# 1            Cạnh tranh  Hồ Chí Minh
# 2            Cạnh tranh  Hồ Chí Minh
# 3     15 Tr - 40 Tr VND  Hồ Chí Minh
# 4            Cạnh tranh  Hồ Chí Minh
# ...                 ...          ...
# 1086  2 Tr - 2,4 Tr VND  Hồ Chí Minh
# 1087         Cạnh tranh  Hồ Chí Minh
# 1088    1 Tr - 2 Tr VND  Hồ Chí Minh
# 1089      Trên 2 Tr VND  Hồ Chí Minh
# 1090    2 Tr - 4 Tr VND  Hồ Chí Minh
#
# [1091 rows x 4 columns]

# %%
df_3
# Out:
#                                         job_title                       date  \
# 0                                  QA Game Tester  2026-01-07T23:59:59+07:00
# 1                   Data and Analytics Supervisor  2025-12-24T23:59:59+07:00
# 2            AI Engineer Khối Công nghệ thông tin  2025-12-27T23:59:59+07:00
# 3    FullStack Developer Khối Công nghệ thông tin  2025-12-27T23:59:59+07:00
# 4                                    Nhân Viên IT  2025-12-24T23:59:59+07:00
# ..                                            ...                        ...
# 704                 Database Reliability Engineer  2025-12-21T23:59:59+07:00
# 705                IT Security & Support Engineer  2025-12-21T23:59:59+07:00
# 706                      ERP Application Engineer  2025-12-21T23:59:59+07:00
# 707                            Nhân Viên Kỹ Thuật  2025-12-21T23:59:59+07:00
# 708                                Java Developer  2025-12-21T23:59:59+07:00
#
#                  salary     location
# 0          Thương lượng  Hồ Chí Minh
# 1          Thương lượng  Hồ Chí Minh
# 2          Thương lượng       Hà Nội
# 3          Thương lượng       Hà Nội
# 4     13tr-15tr ₫/tháng    Hải Phòng
# ..                  ...          ...
# 704  $ 65tr-80tr /tháng  Hồ Chí Minh
# 705        Thương lượng       Hà Nội
# 706        Thương lượng    Hải Phòng
# 707   12tr-25tr ₫/tháng          NaN
# 708    $ 750-950 /tháng  Hồ Chí Minh
#
# [709 rows x 4 columns]

# %%
def format_date(date):
    if pd.isna(date):
        return pd.NaT

    date = str(date)

    # Book3 – ISO 8601
    if 'T' in date:
        return pd.to_datetime(date, errors='coerce').date()

    # Book1, Book2 – dd/mm/yyyy
    return pd.to_datetime(date, format="%d/%m/%Y", errors='coerce').date()

# %%
for name, df in dfs.items():
    if 'date' in df.columns:
        df['date'] = df['date'].apply(format_date)
        df.dropna(subset=['date'], inplace = True)

# %%
df_1
# Out:
#                 job_title        date         salary           location
# 0        Business Analyst  2026-01-03   Tới 25 triệu             Hà Nội
# 1         Chuyên môn khác  2026-02-28     Thoả thuận             Hà Nội
# 2       Software Engineer  2026-01-16  40 - 60 triệu  Hồ Chí Minh (mới)
# 3        Business Analyst  2026-01-15     Thoả thuận             Hà Nội
# 4     Kinh doanh phần mềm  2026-01-15    Từ 20 triệu  Hồ Chí Minh (mới)
# ...                   ...         ...            ...                ...
# 1075       Cloud Engineer  2025-12-31  23 - 27 triệu             Hà Nội
# 1076      Thiết kế đồ họa  2025-12-24     Thoả thuận  Hồ Chí Minh (mới)
# 1077     Network Engineer  2025-12-24     Thoả thuận             Hà Nội
# 1078      Thiết kế đồ họa  2025-12-24    4 - 6 triệu             Hà Nội
# 1079      Thiết kế đồ họa  2025-12-31  12 - 17 triệu             Hà Nội
#
# [1070 rows x 4 columns]

# %%
df_2
# Out:
#                                               job_title        date  \
# 1                             Quality Assurance Manager  2026-01-05
# 3     Sales Leader B2B/ Trưởng Nhóm Kinh Doanh Phần ...  2025-12-25
# 5                   Senior Telecom Operation Specialist  2026-01-19
# 6                               Cloud System Operations  2025-12-20
# 8                                   Senior Data Analyst  2026-01-18
# ...                                                 ...         ...
# 1086                           Backend Developer Intern  2025-12-31
# 1087                            Thực tập sinh Developer  2025-12-20
# 1088                                 AI Engineer Intern  2025-12-31
# 1089                           Thực tập sinh kinh doanh  2025-12-25
# 1090                                  Thực Tập Sinh SEO  2025-12-11
#
#                  salary     location
# 1            Cạnh tranh  Hồ Chí Minh
# 3     15 Tr - 40 Tr VND  Hồ Chí Minh
# 5       900 - 1,500 USD  Hồ Chí Minh
# 6     1,000 - 2,000 USD  Hồ Chí Minh
# 8            Cạnh tranh  Hồ Chí Minh
# ...                 ...          ...
# 1086  2 Tr - 2,4 Tr VND  Hồ Chí Minh
# 1087         Cạnh tranh  Hồ Chí Minh
# 1088    1 Tr - 2 Tr VND  Hồ Chí Minh
# 1089      Trên 2 Tr VND  Hồ Chí Minh
# 1090    2 Tr - 4 Tr VND  Hồ Chí Minh
#
# [1065 rows x 4 columns]

# %%
df_3
# Out:
#                                         job_title        date  \
# 0                                  QA Game Tester  2026-01-07
# 1                   Data and Analytics Supervisor  2025-12-24
# 2            AI Engineer Khối Công nghệ thông tin  2025-12-27
# 3    FullStack Developer Khối Công nghệ thông tin  2025-12-27
# 4                                    Nhân Viên IT  2025-12-24
# ..                                            ...         ...
# 704                 Database Reliability Engineer  2025-12-21
# 705                IT Security & Support Engineer  2025-12-21
# 706                      ERP Application Engineer  2025-12-21
# 707                            Nhân Viên Kỹ Thuật  2025-12-21
# 708                                Java Developer  2025-12-21
#
#                  salary     location
# 0          Thương lượng  Hồ Chí Minh
# 1          Thương lượng  Hồ Chí Minh
# 2          Thương lượng       Hà Nội
# 3          Thương lượng       Hà Nội
# 4     13tr-15tr ₫/tháng    Hải Phòng
# ..                  ...          ...
# 704  $ 65tr-80tr /tháng  Hồ Chí Minh
# 705        Thương lượng       Hà Nội
# 706        Thương lượng    Hải Phòng
# 707   12tr-25tr ₫/tháng          NaN
# 708    $ 750-950 /tháng  Hồ Chí Minh
#
# [709 rows x 4 columns]

# %%
USD_TO_VND = 27000
VND_TO_MILLION = 1000000

# %%
import numpy as np

# %%
def salary_shortcut(salary):
    if pd.isna(salary):
        return np.nan
    
    s = str(salary).lower()
    
    if any(x in s for x in ['thỏa thuận', 'thương lượng', 'cạnh tranh']):
        return np.nan
    
    nums = re.findall(r'\d+[.,]?\d*', s)
    nums = [float(n.replace(',', '')) for n in nums]
    
    if not nums:
        return np.nan
    
    max_value = max(nums)
    
    if 'triệu' in s or 'tr' in s:
        return max_value
    
    if 'usd' in s or '$' in s:
        return round(((max_value * 27000) / 1000000), 2)
    
    
    return np.nan

# %%
for name, df in dfs.items():
    if 'salary' in df.columns:
        df['salary'] = df['salary'].apply(salary_shortcut)
        df.dropna(subset=['salary'], inplace = True)

# %%
df_1
# Out:
#                 job_title        date  salary           location
# 0        Business Analyst  2026-01-03    25.0             Hà Nội
# 2       Software Engineer  2026-01-16    60.0  Hồ Chí Minh (mới)
# 4     Kinh doanh phần mềm  2026-01-15    20.0  Hồ Chí Minh (mới)
# 5            UI/UX Design  2025-12-31    50.0             Hà Nội
# 6         Thiết kế đồ họa  2026-01-16    20.0  Hồ Chí Minh (mới)
# ...                   ...         ...     ...                ...
# 1073  Kinh doanh phần mềm  2025-12-31    60.0             Hà Nội
# 1074  Kinh doanh phần mềm  2025-12-24    40.0             Hà Nội
# 1075       Cloud Engineer  2025-12-31    27.0             Hà Nội
# 1078      Thiết kế đồ họa  2025-12-24     6.0             Hà Nội
# 1079      Thiết kế đồ họa  2025-12-31    17.0             Hà Nội
#
# [640 rows x 4 columns]

# %%
df_2
# Out:
#                                               job_title        date  salary  \
# 3     Sales Leader B2B/ Trưởng Nhóm Kinh Doanh Phần ...  2025-12-25    40.0
# 5                   Senior Telecom Operation Specialist  2026-01-19    40.5
# 6                               Cloud System Operations  2025-12-20    54.0
# 13           Chuyên viên tư vấn triển khai phần mềm ERP  2026-01-15    30.0
# 18    Chuyên viên Phát Triển Ứng Dụng – Mobile & Web...  2026-01-15    35.0
# ...                                                 ...         ...     ...
# 1084                              Thực tập sinh SEO&ASO  2025-12-31     5.0
# 1086                           Backend Developer Intern  2025-12-31    24.0
# 1088                                 AI Engineer Intern  2025-12-31     2.0
# 1089                           Thực tập sinh kinh doanh  2025-12-25     2.0
# 1090                                  Thực Tập Sinh SEO  2025-12-11     4.0
#
#          location
# 3     Hồ Chí Minh
# 5     Hồ Chí Minh
# 6     Hồ Chí Minh
# 13    Hồ Chí Minh
# 18    Hồ Chí Minh
# ...           ...
# 1084       Hà Nội
# 1086  Hồ Chí Minh
# 1088  Hồ Chí Minh
# 1089  Hồ Chí Minh
# 1090  Hồ Chí Minh
#
# [467 rows x 4 columns]

# %%
df_3
# Out:
#                                              job_title        date  salary  \
# 4                                         Nhân Viên IT  2025-12-24   15.00
# 9              Software Project Leader Project Manager  2025-12-27   67.50
# 15                                         AI Engineer  2026-01-02   35.00
# 16                                   Backend Developer  2026-01-08   32.40
# 20   Software Architect Salary Up to 2500$ Hybrid W...  2026-01-10   67.50
# ..                                                 ...         ...     ...
# 701                       Kỹ Sư Lập Trình Web Frontend  2025-12-24  500.00
# 703                                Global Service Desk  2025-12-24   27.00
# 704                      Database Reliability Engineer  2025-12-21   80.00
# 707                                 Nhân Viên Kỹ Thuật  2025-12-21   25.00
# 708                                     Java Developer  2025-12-21   25.65
#
#         location
# 4      Hải Phòng
# 9         Hà Nội
# 15        Hà Nội
# 16   Hồ Chí Minh
# 20       Đà Nẵng
# ..           ...
# 701       Hà Nội
# 703  Hồ Chí Minh
# 704  Hồ Chí Minh
# 707          NaN
# 708  Hồ Chí Minh
#
# [233 rows x 4 columns]

# %%
def location_clean(location):
    if pd.isna(location):
        return np.nan
    
    s = str(location)
    
    # 1. Bỏ nội dung trong ngoặc ()
    s = re.sub(r'\(.*?\)', '', s)
    
    # 2. Nếu có nhiều địa điểm, lấy cái đầu tiên
    s = s.split(',')[0]
    
    # 3. Chuẩn hóa khoảng trắng
    s = re.sub(r'\s+', ' ', s)
    
    return s.strip()

# %%
for name, df in dfs.items():
    if 'location' in df.columns:
        df['location'] = df['location'].apply(location_clean)
        df.dropna(subset=['location'], inplace = True)

# %%
df_1
# Out:
#                 job_title        date  salary     location
# 0        Business Analyst  2026-01-03    25.0       Hà Nội
# 2       Software Engineer  2026-01-16    60.0  Hồ Chí Minh
# 4     Kinh doanh phần mềm  2026-01-15    20.0  Hồ Chí Minh
# 5            UI/UX Design  2025-12-31    50.0       Hà Nội
# 6         Thiết kế đồ họa  2026-01-16    20.0  Hồ Chí Minh
# ...                   ...         ...     ...          ...
# 1073  Kinh doanh phần mềm  2025-12-31    60.0       Hà Nội
# 1074  Kinh doanh phần mềm  2025-12-24    40.0       Hà Nội
# 1075       Cloud Engineer  2025-12-31    27.0       Hà Nội
# 1078      Thiết kế đồ họa  2025-12-24     6.0       Hà Nội
# 1079      Thiết kế đồ họa  2025-12-31    17.0       Hà Nội
#
# [640 rows x 4 columns]

# %%
df_2
# Out:
#                                               job_title        date  salary  \
# 3     Sales Leader B2B/ Trưởng Nhóm Kinh Doanh Phần ...  2025-12-25    40.0
# 5                   Senior Telecom Operation Specialist  2026-01-19    40.5
# 6                               Cloud System Operations  2025-12-20    54.0
# 13           Chuyên viên tư vấn triển khai phần mềm ERP  2026-01-15    30.0
# 18    Chuyên viên Phát Triển Ứng Dụng – Mobile & Web...  2026-01-15    35.0
# ...                                                 ...         ...     ...
# 1084                              Thực tập sinh SEO&ASO  2025-12-31     5.0
# 1086                           Backend Developer Intern  2025-12-31    24.0
# 1088                                 AI Engineer Intern  2025-12-31     2.0
# 1089                           Thực tập sinh kinh doanh  2025-12-25     2.0
# 1090                                  Thực Tập Sinh SEO  2025-12-11     4.0
#
#          location
# 3     Hồ Chí Minh
# 5     Hồ Chí Minh
# 6     Hồ Chí Minh
# 13    Hồ Chí Minh
# 18    Hồ Chí Minh
# ...           ...
# 1084       Hà Nội
# 1086  Hồ Chí Minh
# 1088  Hồ Chí Minh
# 1089  Hồ Chí Minh
# 1090  Hồ Chí Minh
#
# [467 rows x 4 columns]

# %%
df_3
# Out:
#                                              job_title        date  salary  \
# 4                                         Nhân Viên IT  2025-12-24   15.00
# 9              Software Project Leader Project Manager  2025-12-27   67.50
# 15                                         AI Engineer  2026-01-02   35.00
# 16                                   Backend Developer  2026-01-08   32.40
# 20   Software Architect Salary Up to 2500$ Hybrid W...  2026-01-10   67.50
# ..                                                 ...         ...     ...
# 700                            Kỹ Sư Phân Tích Dữ Liệu  2025-12-24  500.00
# 701                       Kỹ Sư Lập Trình Web Frontend  2025-12-24  500.00
# 703                                Global Service Desk  2025-12-24   27.00
# 704                      Database Reliability Engineer  2025-12-21   80.00
# 708                                     Java Developer  2025-12-21   25.65
#
#         location
# 4      Hải Phòng
# 9         Hà Nội
# 15        Hà Nội
# 16   Hồ Chí Minh
# 20       Đà Nẵng
# ..           ...
# 700    Hải Phòng
# 701       Hà Nội
# 703  Hồ Chí Minh
# 704  Hồ Chí Minh
# 708  Hồ Chí Minh
#
# [232 rows x 4 columns]

# %%
df_concatenate = pd.concat(
    [df_1, df_2, df_3], ignore_index=True
)

# %%
df_concatenate
# Out:
#                           job_title        date  salary     location
# 0                  Business Analyst  2026-01-03   25.00       Hà Nội
# 1                 Software Engineer  2026-01-16   60.00  Hồ Chí Minh
# 2               Kinh doanh phần mềm  2026-01-15   20.00  Hồ Chí Minh
# 3                      UI/UX Design  2025-12-31   50.00       Hà Nội
# 4                   Thiết kế đồ họa  2026-01-16   20.00  Hồ Chí Minh
# ...                             ...         ...     ...          ...
# 1334        Kỹ Sư Phân Tích Dữ Liệu  2025-12-24  500.00    Hải Phòng
# 1335   Kỹ Sư Lập Trình Web Frontend  2025-12-24  500.00       Hà Nội
# 1336            Global Service Desk  2025-12-24   27.00  Hồ Chí Minh
# 1337  Database Reliability Engineer  2025-12-21   80.00  Hồ Chí Minh
# 1338                 Java Developer  2025-12-21   25.65  Hồ Chí Minh
#
# [1339 rows x 4 columns]

# %%
# Tổng quan
df_concatenate.shape
# Out:
# (1339, 4)

# %%
df_concatenate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job_title  1339 non-null   object
#  1   date       1339 non-null   object
#  2   salary     1339 non-null   float64
#  3   location   1339 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 42.0+ KB

# %%
#Missing value
df_concatenate.isna().sum()
(df_concatenate.isna().mean() * 100).round(2)
# Out:
# job_title    0.0
# date         0.0
# salary       0.0
# location     0.0
# dtype: float64

# %%
df_duplicates = df_concatenate[
    df_concatenate.duplicated(
        subset=['job_title', 'date', 'salary', 'location'],
        keep=False
    )
]

df_duplicates
# Out:
#                job_title        date  salary     location
# 1      Software Engineer  2026-01-16    60.0  Hồ Chí Minh
# 3           UI/UX Design  2025-12-31    50.0       Hà Nội
# 4        Thiết kế đồ họa  2026-01-16    20.0  Hồ Chí Minh
# 5      Software Engineer  2026-01-09    45.0       Hà Nội
# 7         Game Developer  2026-01-04    12.0       Hà Nội
# ...                  ...         ...     ...          ...
# 989     Business Analyst  2026-01-04    20.0       Hà Nội
# 1024  Senior IT Security  2025-12-29    40.0       Hà Nội
# 1025  Senior IT Security  2025-12-29    40.0       Hà Nội
# 1265         Kỹ Sư AI CV  2025-12-24   500.0       Hà Nội
# 1267         Kỹ Sư AI CV  2025-12-24   500.0       Hà Nội
#
# [160 rows x 4 columns]

# %%
df_concatenate = df_concatenate.drop_duplicates()

# %%
job_count = df_concatenate['job_title'].value_counts().head(60)

# %%
job_count
# Out:
# job_title
# Thiết kế đồ họa                                            151
# Kinh doanh phần mềm                                         60
# Business Analyst                                            32
# Backend Developer                                           29
# Animation Design                                            21
# Software Engineer                                           20
# Chuyên môn Công nghệ thông tin khác                         19
# Mobile Developer                                            18
# Manual Tester                                               16
# AI Engineer                                                 15
# Data Analyst                                                13
# UI/UX Design                                                12
# Fullstack Developer                                         12
# IT Project Manager                                          11
# IT Helpdesk/IT support                                       9
# Software Tester                                              9
# Frontend Developer                                           8
# Concept Artist                                               8
# Kỹ thuật IT                                                  8
# DevOps Engineer                                              8
# Product Owner/Product Manager                                8
# Game Design                                                  7
# Kinh doanh Domain/Hosting/Server                             6
# Kỹ sư lập trình máy                                          6
# System Administrator                                         6
# Data Engineer                                                5
# Lập trình viên                                               5
# Game Developer                                               5
# Digital Marketing                                            5
# Nhân Viên IT                                                 5
# Chuyên môn khác                                              5
# Network Engineer                                             5
# Sales IT Phần mềm khác                                       5
# CHUYÊN VIÊN PHÂN TÍCH NGHIỆP VỤ ERP                          5
# Chuyên Viên Phân Tích Nghiệp Vụ                              4
# Product Owner                                                4
# Database Administrator                                       4
# Chuyên viên IT                                               4
# System Engineer                                              4
# 10 Kỹ Sư Thiết Kế Cơ Khí R&D Mechanical Design Engineer      4
# Kỹ sư hệ thống                                               4
# Kỹ sư cơ khí                                                 4
# Java Developer                                               3
# Kỹ sư IoT                                                    3
# 3D Modeler                                                   3
# Nhân viên IT                                                 3
# Bán hàng kỹ thuật IT                                         3
# Chuyên viên Phân tích Nghiệp vụ                              3
# Illustration                                                 3
# Chuyên viên phân tích nghiệp vụ BA                           3
# IT Consultant                                                3
# Flutter Developer                                            3
# Nhân Viên Công Nghệ Thông Tin                                3
# Kỹ sư lập trình PLC/SCADA                                    3
# UX/UI Designer                                               3
# Nhân viên IT Helpdesk                                        3
# Devops Engineer                                              3
# CHUYÊN VIÊN LẬP TRÌNH PYTHON ODOO                            3
# Hà Nội Nhân viên Kỹ thuật Viễn thông                         2
# Trưởng Bộ Phận Hành Chính Nhân Sự                            2
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 5))
job_count.plot(kind='bar', ax = ax)
ax.set_title('All job titles')
ax.set_xlabel('Job titles')
ax.set_ylabel('Number of jobs')

ax.bar_label(ax.containers[0])
 
plt.xticks(rotation = 45, ha = 'right')
plt.tight_layout()
plt.show()

# %%
salary_filter = df_concatenate['salary'][df_concatenate['salary'] > 200]
salary_filter
# Out:
# 703     5000.0
# 1118    1890.0
# 1119    2295.0
# 1134    1485.0
# 1141     486.0
# 1163    1485.0
# 1165     700.0
# 1174    1485.0
# 1214     589.0
# 1254     700.0
# 1255     700.0
# 1256     500.0
# 1257     700.0
# 1258     500.0
# 1259     500.0
# 1260     500.0
# 1261     700.0
# 1262     700.0
# 1263     500.0
# 1264     700.0
# 1265     500.0
# 1266     500.0
# 1270     589.0
# 1271     700.0
# 1272     500.0
# 1274     500.0
# 1316     500.0
# 1317     500.0
# 1331     500.0
# 1332     500.0
# 1333     500.0
# 1334     500.0
# 1335     500.0
# Name: salary, dtype: float64

# %%
salary_filtered = df_concatenate['salary'][df_concatenate['salary'] < 200]
plt.figure(figsize=(8, 5))
salary_filtered.dropna().plot(kind = 'hist', bins = 20)
plt.title('Salary distribution')
plt.xlabel('Salary(Mil VND)')
plt.ylabel('frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(
    df_concatenate['salary'][df_concatenate['salary'] < 200],
    vert=False
)
plt.title('Salary Boxplot')
plt.xlabel('Salary (Mil VND)')
plt.tight_layout()
plt.show()

# %%
top_locations = df_concatenate['location'].value_counts().head(5).index

data = df_concatenate[
    (df_concatenate['location'].isin(top_locations)) &
    (df_concatenate['salary'] < 200)
]

plt.figure(figsize=(12, 5))

data.boxplot(
    column='salary',
    by='location'
)

plt.title('Salary by Location (Salary > 200)')
plt.suptitle('')
plt.xlabel('Location')
plt.ylabel('Salary (Mil VND)')
plt.tight_layout()
plt.show()

# %%
df_concatenate = df_concatenate[df_concatenate['salary'] < 200]

# %%
df_concatenate['salary'].describe()
# Out:
# count    1217.000000
# mean       29.370362
# std        20.962953
# min         0.500000
# 25%        15.000000
# 50%        25.000000
# 75%        35.000000
# max       189.000000
# Name: salary, dtype: float64

# %%
df_concatenate.to_csv('cleaned.csv', encoding= 'utf-8-sig')
